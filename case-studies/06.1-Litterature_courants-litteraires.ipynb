# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key  = os.getenv('OPENAI_API_KEY')

client = openai.OpenAI()

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
prompt = f"""
Génère une liste des courants et mouvements littéraires majeurs de l'histoire littéraire. 
Pour chaque courant ou mouvement, indique son nom, la période principale de son développement 
(par exemple : fin du 19ᵉ siècle, années 1920), ses caractéristiques stylistiques ou idéologiques principales, 
et un ou deux auteurs emblématiques associés à ce courant. 
Fournis les données au format JSON avec les clés suivantes : 
courant_id, nom, période, caractéristiques, auteurs_phares.
"""

response = get_completion(prompt)
print(response)
# Out:
# [
#     {
#         "courant_id": 1,
#         "nom": "Romantisme",
#         "période": "Fin du 18ᵉ siècle - milieu du 19ᵉ siècle",
#         "caractéristiques": "Valorisation de l'émotion, de la nature, de l'individu, critique de la société, recherche de l'exotisme et du fantastique",
#         "auteurs_phares": ["Victor Hugo", "Alfred de Musset"]
#     },
#     {
#         "courant_id": 2,
#         "nom": "Symbolisme",
#         "période": "Fin du 19ᵉ siècle",
#         "caractéristiques": "Recherche de l'absolu, du mystère, de l'inconscient, utilisation de symboles et de métaphores",
#         "auteurs_phares": ["Stéphane Mallarmé", "Arthur Rimbaud"]
#     },
#     {
#         "courant_id": 3,
#         "nom": "Surréalisme",
#         "période": "Années 1920 - années 1950",
#         "caractéristiques": "Exploration de l'inconscient, du rêve, du surréalisme, rejet des normes et de la logique",
#         "auteurs_phares": ["André Breton", "Paul Éluard"]
#     },
#     {
# ...

# %%
prompt = f"""
Génère une liste de tous courants et mouvements littéraires majeurs de l'histoire littéraire. 
Pour chaque courant ou mouvement, indique son nom, la période principale de son développement 
(par exemple : fin du 19ᵉ siècle, années 1920), ses caractéristiques stylistiques ou idéologiques principales, 
et un ou deux auteurs emblématiques associés à ce courant. 
Fournis les données au format JSON avec les clés suivantes : 
nom, période, caractéristiques, auteurs_phares.
"""
response = get_completion(prompt)
print(response)
# Out:
# {
#     "courants_litteraires": [
#         {
#             "nom": "Classicisme",
#             "periode": "17ᵉ siècle",
#             "caracteristiques": "Recherche de l'harmonie, de la mesure et de la clarté. Valorisation de la raison et de la nature. Respect des règles de la poésie classique.",
#             "auteurs_phares": ["Jean Racine", "Molière"]
#         },
#         {
#             "nom": "Romantisme",
#             "periode": "Début du 19ᵉ siècle",
#             "caracteristiques": "Valorisation des sentiments, de l'imagination et de la nature. Rejet des règles classiques. Mise en avant de l'individu et de ses émotions.",
#             "auteurs_phares": ["Victor Hugo", "George Sand"]
#         },
#         {
#             "nom": "Symbolisme",
#             "periode": "Fin du 19ᵉ siècle",
#             "caracteristiques": "Recherche de l'absolu, du mystère et de l'inconscient. Importance de la suggestion et du symbole. Esthétique de la musicalité et de la couleur.",
# ...

# %%
prompt = f"""
Génère une liste de 20 courants et mouvements littéraires de l'histoire littéraire. 

Pour chaque courant ou mouvement, indique son nom, la période principale de son développement, 
ses caractéristiques stylistiques ou idéologiques principales, 
et un ou deux auteurs emblématiques associés à ce courant. 

Fournis les données au format JSON avec les clés suivantes : 
id, nom, définition, période, caractéristiques, auteurs_phares.
"""
response = get_completion(prompt)
print(response)
# Out:
# [
#     {
#         "id": 1,
#         "nom": "Classicisme",
#         "définition": "Courant littéraire prônant la recherche de l'harmonie, de la mesure et de la clarté.",
#         "période": "XVIIe siècle",
#         "caractéristiques": "Rigueur formelle, respect des règles, valorisation de la raison et de la nature.",
#         "auteurs_phares": ["Jean Racine", "Molière"]
#     },
#     {
#         "id": 2,
#         "nom": "Romantisme",
#         "définition": "Mouvement artistique et littéraire prônant l'expression des sentiments et des émotions.",
#         "période": "XIXe siècle",
#         "caractéristiques": "Valorisation de l'individu, de la nature, du rêve et de l'imagination.",
#         "auteurs_phares": ["Victor Hugo", "George Sand"]
#     },
#     {
#         "id": 3,
#         "nom": "Naturalisme",
#         "définition": "Courant littéraire mettant en avant la description réaliste et scientifique de la société.",
#         "période": "XIXe siècle",
# ...
